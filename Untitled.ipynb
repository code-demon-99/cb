# %%
import pandas as pd 
import sqlite3

# %%
con=sqlite3.connect('db.sqlite3')

# %%
data_query = "select id,PatientNumber, AgeBracket,Gender,DetectedState,DetectedCity,DetectedDistrict from model_coviddata"

# %%
df = pd.read_sql_query(data_query,con)

# %%
df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10819 entries, 0 to 10818
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                10819 non-null  int64
#  1   PatientNumber     10819 non-null  object
#  2   AgeBracket        10819 non-null  object
#  3   Gender            10819 non-null  object
#  4   DetectedState     10819 non-null  object
#  5   DetectedCity      10819 non-null  object
#  6   DetectedDistrict  10819 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 591.8+ KB

# %%
dir(df)

# %%
df2=pd.DataFrame(df.groupby('DetectedCity'))

# %%
df.reindex(df['id'])
# Out:
#           id PatientNumber AgeBracket Gender DetectedState DetectedCity  \
# id
# 0          0         17307         48      M        Odisha
# 1          1         17308         55      M        Odisha
# 2          2         17309         57      M        Odisha
# 3          3         17310         58      M        Odisha
# 4          4         17311         66      M        Odisha
# ...      ...           ...        ...    ...           ...          ...
# 10814  10814                                   Maharashtra
# 10815  10815                                   Maharashtra
# 10816  10816                                   Maharashtra
# 10817  10817                                   Maharashtra
# 10818  10818                                   Maharashtra
#
#       DetectedDistrict
# id
# 0              Bhadrak
# 1              Bhadrak
# 2              Bhadrak
# 3              Bhadrak
# 4              Bhadrak
# ...                ...
# 10814
# 10815           Nagpur
# 10816
# ...

# %%
df2 = df[['PatientNumber','AgeBracket','Gender','DetectedState','De']]

# %%
df2.set_index(df['PatientNumber'],inplace=True)

# %%
df2.head()
# Out:
#               PatientNumber AgeBracket Gender DetectedState
# PatientNumber
# 17307                 17307         48      M        Odisha
# 17308                 17308         55      M        Odisha
# 17309                 17309         57      M        Odisha
# 17310                 17310         58      M        Odisha
# 17311                 17311         66      M        Odisha

# %%
df2.tail()
# Out:
#               PatientNumber AgeBracket Gender DetectedState
# PatientNumber
#                                                 Maharashtra
#                                                 Maharashtra
#                                                 Maharashtra
#                                                 Maharashtra
#                                                 Maharashtra

# %%
df1 = df.groupby('DetectedCity')

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-152-bd8bfd29537a> in <module>
#       1 m=0
#       2 for col in df1:
# ----> 3     for gender in  col[0]['Gender']:
#       4         if gender =='M':
#       5             m+=1
#
# TypeError: string indices must be integers

# %%
dir(df1)
# Out:
# ['__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_accessors',
#  '_add_numeric_operations',
#  '_agg_examples_doc',
#  '_agg_see_also_doc',
#  '_aggregate',
#  '_aggregate_multiple_funcs',
#  '_aggregate_named',
#  '_apply_filter',
#  '_apply_to_column_groupbys',
#  '_apply_whitelist',
#  '_assure_grouper',
#  '_bool_agg',
#  '_builtin_table',
#  '_concat_objects',
#  '_constructor',
#  '_cumcount_array',
#  '_cython_agg_general',
#  '_cython_table',
#  '_cython_transform',
#  '_deprecations',
#  '_dir_additions',
# ...
